# %% [markdown]
# ## MFCC features

# %%
import numpy
import math

def framesig(sig,frame_len,frame_step,winfunc=lambda x:numpy.ones((1,x))):
    slen = len(sig)
    frame_len = int(round(frame_len))
    frame_step = int(round(frame_step))
    if slen <= frame_len: 
        numframes = 1
    else:
        numframes = 1 + int(math.ceil((1.0*slen - frame_len)/frame_step))
    padlen = int((numframes-1)*frame_step + frame_len)
    zeros = numpy.zeros((padlen - slen,))
    padsignal = numpy.concatenate((sig,zeros))
    indices = numpy.tile(numpy.arange(0,frame_len),(numframes,1)) + numpy.tile(numpy.arange(0,numframes*frame_step,frame_step),(frame_len,1)).T
    indices = numpy.array(indices,dtype=numpy.int32)
    frames = padsignal[indices]
    win = numpy.tile(winfunc(frame_len),(numframes,1))
    return frames*win
    
def magspec(frames,NFFT):
    complex_spec = numpy.fft.rfft(frames,NFFT)
    return numpy.absolute(complex_spec)
          
def powspec(frames,NFFT):
    return 1.0/NFFT * numpy.square(magspec(frames,NFFT))
    
def preemphasis(signal,coeff=0.95):
    return numpy.append(signal[0],signal[1:]-coeff*signal[:-1])

# %%
import numpy
from scipy.fftpack import dct

def mfcc(signal,samplerate=16000,winlen=0.025,winstep=0.01,numcep=13,nfilt=26,nfft=512,lowfreq=0,highfreq=None,preemph=0.97,ceplifter=22,appendEnergy=True):
    feat,energy = fbank(signal,samplerate,winlen,winstep,nfilt,nfft,lowfreq,highfreq,preemph)
    feat = numpy.log(feat)
    feat = dct(feat, type=2, axis=1, norm='ortho')[:,:numcep]
    feat = lifter(feat,ceplifter)
    if appendEnergy:
        feat[:,0] = numpy.log(energy)
    return feat

def fbank(signal,samplerate=16000,winlen=0.025,winstep=0.01,nfilt=26,nfft=512,lowfreq=0,highfreq=None,preemph=0.97):
    highfreq= highfreq or samplerate/2
    signal = preemphasis(signal,preemph)
    frames = framesig(signal, winlen*samplerate, winstep*samplerate)
    pspec = powspec(frames,nfft)
    energy = numpy.sum(pspec,1)                                     # this stores the total energy in each frame
    energy = numpy.where(energy == 0,numpy.finfo(float).eps,energy) # if energy is zero, we get problems with log
    fb = get_filterbanks(nfilt,nfft,samplerate)
    feat = numpy.dot(pspec,fb.T)                                    # compute the filterbank energies
    feat = numpy.where(feat == 0,numpy.finfo(float).eps,feat)       # if feat is zero, we get problems with log
    return feat,energy

def hz2mel(hz):
    return 2595 * numpy.log10(1+hz/700.0)
    
def mel2hz(mel):
    return 700*(10**(mel/2595.0)-1)

def get_filterbanks(nfilt=20,nfft=512,samplerate=16000,lowfreq=0,highfreq=None):
    highfreq= highfreq or samplerate/2
    # compute points evenly spaced in mels
    lowmel = hz2mel(lowfreq)
    highmel = hz2mel(highfreq)
    melpoints = numpy.linspace(lowmel,highmel,nfilt+2)
    # our points are in Hz, but we use fft bins, so we have to convert
    #  from Hz to fft bin number
    bin = numpy.floor((nfft+1)*mel2hz(melpoints)/samplerate)
#     print nfilt,nfft/2+1
    fbank = numpy.zeros([nfilt,int(nfft/2+1)])
    for j in xrange(0,nfilt):
        for i in xrange(int(bin[j]),int(bin[j+1])):
            fbank[j,i] = (i - bin[j])/(bin[j+1]-bin[j])
        for i in xrange(int(bin[j+1]),int(bin[j+2])):
            fbank[j,i] = (bin[j+2]-i)/(bin[j+2]-bin[j+1])
    return fbank                 
    
def lifter(cepstra,L=22):
    if L > 0:
        nframes,ncoeff = numpy.shape(cepstra)
        n = numpy.arange(ncoeff)
        lift = 1+ (L/2)*numpy.sin(numpy.pi*n/L)
        return lift*cepstra
    else:
        # values of L <= 0, do nothing
        return cepstra

# %% [markdown]
# # SVM (Support Vector Machine)

# %%
from __future__ import division

import csv
import os.path
import numpy as np
import scipy.io.wavfile as wavfile

from sklearn import svm

class trainModel():
    def __init__(self, data_dir):
        self.data_dir = os.path.abspath(data_dir)
        self.train_file = "training_data.csv"
        
        self.gen_features()
        mfcc_list, speaker_names = self.get_tdata()
        
        # generate speaker_ids from speaker_names
        self.spkr_ntoi = {}
        self.spkr_iton = {}

        i = 0 
        for name in speaker_names:
            if name not in self.spkr_ntoi:
                self.spkr_ntoi[name] = i
                self.spkr_iton[i] = name
                i += 1
        speaker_ids = map(lambda n: self.spkr_ntoi[n], speaker_names)
        
        # train a linear svm now
        self.recognizer = svm.LinearSVC()
        self.recognizer.fit(mfcc_list, speaker_ids)

    def mfcc_to_fvec(self, ceps):
        mean = np.mean(ceps, axis=0)                               # calculate the mean 
        std = np.std(ceps, axis=0)                                 # and standard deviation of MFCC vectors 
        fvec = np.concatenate((mean, std)).tolist()                # use [mean, std] as the feature vector
        return fvec
        
    def gen_features(self):
        with open(self.train_file, 'w') as ohandle:
            melwriter = csv.writer(ohandle)
            speakers = os.listdir(self.data_dir)
            
            for spkr_dir in speakers:
                for soundclip in os.listdir(os.path.join(self.data_dir, spkr_dir)):
                    clip_path = os.path.abspath(os.path.join(self.data_dir, spkr_dir, soundclip))
                    sample_rate, data = wavfile.read(clip_path)
                    mfcc_vectors = mfcc(data, sample_rate)
                
                    feature_vector = self.mfcc_to_fvec(mfcc_vectors)
                    feature_vector.append(spkr_dir)
                    melwriter.writerow(feature_vector)

    def get_tdata(self):
        mfcc_list = []
        speaker_names = []

        with open(self.train_file, 'r') as icsv_handle:
            melreader = csv.reader(icsv_handle)
            for row in melreader:
                mfcc_list.append(map(float, row[:-1]))
                speaker_names.append(row[-1])
        return mfcc_list, speaker_names
        
        
    def predict(self, soundclip):
        sample_rate, data = wavfile.read(os.path.abspath(soundclip))
        ceps = mfcc(data, sample_rate)
        fvec = self.mfcc_to_fvec(ceps)
        speaker_id = self.recognizer.predict([fvec])[0]
        return self.spkr_iton[speaker_id]



if __name__ == "__main__":
    trained_model = trainModel("train_data")

    test_dir = os.path.abspath("test_data")
    testset_size = 0
    testset_error = 0

    for spkr_dir in os.listdir(test_dir):
        for soundclip in os.listdir(os.path.join(test_dir, spkr_dir)):
            clippath = os.path.abspath(os.path.join(test_dir, spkr_dir, soundclip))
            prediction = trained_model.predict(clippath)
            
            testset_size += 1
            if prediction != spkr_dir:
                testset_error += 1    
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2717]")
            else:
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2713]")

    if testset_size == 0:
        print "No test data available."
    else:
        print "Error on test data: %.2f%%\n" % (testset_error / testset_size * 100)
        print "Accuracy : %.2f%%\n" % (100-(testset_error / testset_size * 100))
# Out:
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# artk artk [✓]
# ax artk [✗]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# bhuvan asladic [✗]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# Bahoke AslakKnutsen [✗]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# belmontguy asp [✗]
# asp asp [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# bluepeppers ax [✗]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bae bae [✓]
# bae bae [✓]
# Bahoke bae [✗]
# bae bae [✓]
# bae bae [✓]
# Bahoke Bahoke [✓]
# ben Bahoke [✗]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# bluepeppers becz03 [✗]
# becz03 becz03 [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# bhavanikrishna benoliver999 [✗]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# belmontguy BhushanNKIITBombay [✗]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# bachroxx BigMick [✗]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# Bahoke bloomtom [✗]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# Bahoke BlueAgent [✗]
# BlueAgent BlueAgent [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# Error on test data: 3.86%
#
# Accuracy : 96.14%

# %% [markdown]
# # GMM (Gaussian Mixture Model)

# %%
import numpy as np
from sklearn import preprocessing

def calculate_delta(array):
    rows,cols = array.shape
    deltas = np.zeros((rows,20))
    N = 2
    for i in range(rows):
        index = []
        j = 1
        while j <= N:
            if i-j < 0:
                first = 0
            else:
                first = i-j
            if i+j > rows -1:
                second = rows -1
            else:
                second = i+j
            index.append((second,first))
            j+=1
        deltas[i] = ( array[index[0][0]]-array[index[0][1]] + (2 * (array[index[1][0]]-array[index[1][1]])) ) / 10
    return deltas

def extract_features(audio,rate):
    mfcc_feat = mfcc(audio,rate, 0.025, 0.01, 20, appendEnergy = True)
#     mfcc_feat = preprocessing.scale(mfcc_feat)
#     delta = calculate_delta(mfcc_feat)
#     combined = np.hstack((mfcc_feat,delta)) 
    return mfcc_feat

# %%
import cPickle
import numpy as np
from scipy.io.wavfile import read
from sklearn.mixture import GMM
import warnings
warnings.filterwarnings("ignore")

dest = "speaker_models\\"

def trainModel(data_dir = "train_data"):
    speakers = os.listdir(data_dir)

    features = np.asarray(())

    for spkr_dir in speakers:
        for soundclip in os.listdir(os.path.join(data_dir, spkr_dir)):
            clip_path = os.path.abspath(os.path.join(data_dir, spkr_dir, soundclip))
            sample_rate, data = read(clip_path)

            vector = extract_features(data,sample_rate)

            if features.size == 0:
                features = vector
            else:
                features = np.vstack((features, vector))

        gmm = GMM(n_components = 16, n_iter = 200, covariance_type='diag', n_init = 3)  # n_iter = 500 => 100% accuracy
        gmm.fit(features)

        picklefile = spkr_dir+".gmm"
        cPickle.dump(gmm,open(dest + picklefile,'w'))
#         print 'Modeling completed for speaker:',picklefile," with data point = ",features.shape
        features = np.asarray(())
trainModel()

# %%
import os
import cPickle
import numpy as np
from scipy.io.wavfile import read
import warnings
warnings.filterwarnings("ignore")

modelpath = "speaker_models\\"

gmm_files = [os.path.join(modelpath,fname) for fname in os.listdir(modelpath) if fname.endswith('.gmm')]

# Load the Gaussian Models
models    = [cPickle.load(open(fname,'r')) for fname in gmm_files]
speakers   = [fname.split("\\")[-1].split(".gmm")[0] for fname in gmm_files]


test_dir = os.path.abspath("test_data")
testset_size = 0
testset_error = 0

for spkr_dir in os.listdir(test_dir):
    for soundclip in os.listdir(os.path.join(test_dir, spkr_dir)):
        clip_path = os.path.abspath(os.path.join(test_dir, spkr_dir, soundclip))
        sample_rate, data = read(clip_path)

        vector = extract_features(data,sample_rate)
        log_likelihood = np.zeros(len(models)) 

        for i in range(len(models)):         #checking with each model one by one
            gmm    = models[i]
            scores = np.array(gmm.score(vector))
            log_likelihood[i] = scores.sum()
        winner = np.argmax(log_likelihood)

        testset_size += 1
        if speakers[winner] != spkr_dir:
            testset_error += 1    
            print "%s %s %s " % (speakers[winner], spkr_dir, u"[\u2717]")
        else:
            print "%s %s %s " % (speakers[winner], spkr_dir, u"[\u2713]")

if testset_size == 0:
    print "No test data available."
else:
    print "Error on test data: %.2f%%\n" % (testset_error / testset_size * 100)
    print "Accuracy : %.2f%%\n" % (100-(testset_error / testset_size * 100))
# Out:
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# ataru80 ataru [✗]
# ataru80 ataru [✗]
# ataru80 ataru [✗]
# ataru80 ataru [✗]
# ataru80 ataru [✗]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# avsa avsa [✓]
# avsa242 avsa [✗]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# B B [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bahoke Bahoke [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# asalkeld bendauphinee [✗]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# Error on test data: 2.08%
#
# Accuracy : 97.92%

# %% [markdown]
# # Decision Tree

# %%
from __future__ import division

import csv
import os.path
import numpy as np
import scipy.io.wavfile as wavfile

from sklearn import tree

class trainModel():
    def __init__(self, data_dir):
        self.data_dir = os.path.abspath(data_dir)
        self.train_file = "training_data.csv"
        
        self.gen_features()
        mfcc_list, speaker_names = self.get_tdata()
        
        # generate speaker_ids from speaker_names
        self.spkr_ntoi = {}
        self.spkr_iton = {}

        i = 0 
        for name in speaker_names:
            if name not in self.spkr_ntoi:
                self.spkr_ntoi[name] = i
                self.spkr_iton[i] = name
                i += 1
        speaker_ids = map(lambda n: self.spkr_ntoi[n], speaker_names)
        
        # train a decision tree now
        self.clf = tree.DecisionTreeClassifier(criterion='entropy', splitter='best', max_depth=None, min_samples_split=2,
                                               min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None,
                                               random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0,
                                               min_impurity_split=None, class_weight=None, presort=True)
        self.clf = self.clf.fit(mfcc_list, speaker_ids)

    def mfcc_to_fvec(self, ceps):
        mean = np.mean(ceps, axis=0)                               # calculate the mean 
        std = np.std(ceps, axis=0)                                 # and standard deviation of MFCC vectors 
        fvec = np.concatenate((mean, std)).tolist()                # use [mean, std] as the feature vector
        return fvec
        
    def gen_features(self):
        with open(self.train_file, 'w') as ohandle:
            melwriter = csv.writer(ohandle)
            speakers = os.listdir(self.data_dir)
            
            for spkr_dir in speakers:
                for soundclip in os.listdir(os.path.join(self.data_dir, spkr_dir)):
                    clip_path = os.path.abspath(os.path.join(self.data_dir, spkr_dir, soundclip))
                    sample_rate, data = wavfile.read(clip_path)
                    mfcc_vectors = mfcc(data, sample_rate)
                
                    feature_vector = self.mfcc_to_fvec(mfcc_vectors)
                    feature_vector.append(spkr_dir)
                    melwriter.writerow(feature_vector)

    def get_tdata(self):
        mfcc_list = []
        speaker_names = []

        with open(self.train_file, 'r') as icsv_handle:
            melreader = csv.reader(icsv_handle)
            for row in melreader:
                mfcc_list.append(map(float, row[:-1]))
                speaker_names.append(row[-1])
        return mfcc_list, speaker_names
        
        
    def predict(self, soundclip):
        sample_rate, data = wavfile.read(os.path.abspath(soundclip))
        ceps = mfcc(data, sample_rate)
        fvec = self.mfcc_to_fvec(ceps)
        speaker_id = self.clf.predict([fvec])[0]
        return self.spkr_iton[speaker_id]



if __name__ == "__main__":
    trained_model = trainModel("train_data")

    test_dir = os.path.abspath("test_data")
    testset_size = 0
    testset_error = 0

    for spkr_dir in os.listdir(test_dir):
        for soundclip in os.listdir(os.path.join(test_dir, spkr_dir)):
            clippath = os.path.abspath(os.path.join(test_dir, spkr_dir, soundclip))
            prediction = trained_model.predict(clippath)
            
            testset_size += 1
            if prediction != spkr_dir:
                testset_error += 1    
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2717]")
            else:
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2713]")

    if testset_size == 0:
        print "No test data available."
    else:
        print "Error on test data: %.2f%%\n" % (testset_error / testset_size * 100)
        print "Accuracy : %.2f%%\n" % (100-(testset_error / testset_size * 100))
# Out:
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# Berrym arjuan [✗]
# bluepeppers arjuan [✗]
# bluepeppers arjuan [✗]
# bluepeppers arjuan [✗]
# bluepeppers arjuan [✗]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# bachroxx arthur [✗]
# bluSch arthur [✗]
# Bassel arthur [✗]
# artk artk [✓]
# artk artk [✓]
# Blenderkitty artk [✗]
# artk artk [✓]
# beady artk [✗]
# arun arun [✓]
# azmisov arun [✗]
# arun arun [✓]
# ariyan arun [✗]
# arun arun [✓]
# BlueB arvala [✗]
# ax arvala [✗]
# BlueB arvala [✗]
# arvala arvala [✓]
# bachroxx arvala [✗]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asalkeld asladic [✗]
# asladic asladic [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# becz03 AslakKnutsen [✗]
# AslakKnutsen AslakKnutsen [✓]
# azmisov AslakKnutsen [✗]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# Bassel asp [✗]
# asp asp [✓]
# Blenderkitty AT [✗]
# Bassel AT [✗]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# BlueB ataru [✗]
# ataru ataru [✓]
# BobHallstrom ataru [✗]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# bdutta audioodyssey [✗]
# BlueB audioodyssey [✗]
# bluSch audioodyssey [✗]
# beez1717 audioodyssey [✗]
# audioodyssey audioodyssey [✓]
# bachroxx avsa [✗]
# avsa avsa [✓]
# avsa avsa [✓]
# bachroxx avsa [✗]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# bachroxx avsa [✗]
# avsa avsa [✓]
# bachroxx avsa [✗]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# atterer ax [✗]
# ax ax [✓]
# ax ax [✓]
# Bahoke ax [✗]
# ax ax [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# Apple_Eater axllaruse [✗]
# Bareford azmisov [✗]
# Bareford azmisov [✗]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# Bareford azmisov [✗]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# BigMick bachroxx [✗]
# BigMick bachroxx [✗]
# bachroxx bachroxx [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# azmisov Bareford [✗]
# Bareford Bareford [✓]
# azmisov Bareford [✗]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bassel [✗]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# beady beady [✓]
# beady beady [✓]
# bae beady [✗]
# bebe beady [✗]
# bebe beady [✗]
# BFG bebe [✗]
# bebe bebe [✓]
# BFG bebe [✗]
# bebe bebe [✓]
# BFG bebe [✗]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# Bareford belmontguy [✗]
# belmontguy belmontguy [✓]
# ben ben [✓]
# arjuan ben [✗]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# bencoder bencoder [✓]
# argail bencoder [✗]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# asalkeld bendauphinee [✗]
# asalkeld bendauphinee [✗]
# BlueAgent bendauphinee [✗]
# asalkeld bendauphinee [✗]
# azmisov bendauphinee [✗]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# Blenderkitty benob [✗]
# benob benob [✓]
# Blenderkitty benob [✗]
# benob benob [✓]
# benob benob [✓]
# bebe benoliver999 [✗]
# bebe benoliver999 [✗]
# blood benoliver999 [✗]
# blood benoliver999 [✗]
# benoliver999 benoliver999 [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bae bhart [✗]
# bhart bhart [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# beady BhushanNKIITBombay [✗]
# benoliver999 BhushanNKIITBombay [✗]
# BobHallstrom BhushanNKIITBombay [✗]
# beady BhushanNKIITBombay [✗]
# BobHallstrom BhushanNKIITBombay [✗]
# axllaruse bhuvan [✗]
# bhuvan bhuvan [✓]
# asladic bhuvan [✗]
# bhuvan bhuvan [✓]
# Apple_Eater bhuvan [✗]
# BigMick BigMick [✓]
# blood BigMick [✗]
# bachroxx BigMick [✗]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blenderkitty Blenderkitty [✓]
# blood Blenderkitty [✗]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# bachroxx BlindPilot [✗]
# BlindPilot BlindPilot [✓]
# ataru BlindPilot [✗]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BobHallstrom blood [✗]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bachroxx BlueAgent [✗]
# arvala BlueAgent [✗]
# BlueAgent BlueAgent [✓]
# arvala BlueAgent [✗]
# arvala BlueAgent [✗]
# arvala BlueB [✗]
# atamur BlueB [✗]
# BlueB BlueB [✓]
# arvala BlueB [✗]
# BlueB BlueB [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# Ara bluSch [✗]
# BobHallstrom bluSch [✗]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# atterer BobHallstrom [✗]
# AT bobriva123 [✗]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# AT bobriva123 [✗]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# Error on test data: 27.52%
#
# Accuracy : 72.48%

# %% [markdown]
# # Neural Network

# %%
from __future__ import division

import csv
import os.path
import numpy as np
import scipy.io.wavfile as wavfile

from sklearn.neural_network import MLPClassifier

class trainModel():
    def __init__(self, data_dir):
        self.data_dir = os.path.abspath(data_dir)
        self.train_file = "training_data.csv"
        
        self.gen_features()
        mfcc_list, speaker_names = self.get_tdata()
        
        # generate speaker_ids from speaker_names
        self.spkr_ntoi = {}
        self.spkr_iton = {}

        i = 0 
        for name in speaker_names:
            if name not in self.spkr_ntoi:
                self.spkr_ntoi[name] = i
                self.spkr_iton[i] = name
                i += 1
        speaker_ids = map(lambda n: self.spkr_ntoi[n], speaker_names)
        
        # train a neural network now
        self.clf = MLPClassifier(hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
                                 batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
                                 power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, 
                                 verbose=False, warm_start=True, momentum=0.9, nesterovs_momentum=True, 
                                 early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
        self.clf = self.clf.fit(mfcc_list, speaker_ids)

    def mfcc_to_fvec(self, ceps):
        mean = np.mean(ceps, axis=0)                               # calculate the mean 
        std = np.std(ceps, axis=0)                                 # and standard deviation of MFCC vectors 
        fvec = np.concatenate((mean, std)).tolist()                # use [mean, std] as the feature vector
        return fvec
        
    def gen_features(self):
        with open(self.train_file, 'w') as ohandle:
            melwriter = csv.writer(ohandle)
            speakers = os.listdir(self.data_dir)
            
            for spkr_dir in speakers:
                for soundclip in os.listdir(os.path.join(self.data_dir, spkr_dir)):
                    clip_path = os.path.abspath(os.path.join(self.data_dir, spkr_dir, soundclip))
                    sample_rate, data = wavfile.read(clip_path)
                    mfcc_vectors = mfcc(data, sample_rate)
                
                    feature_vector = self.mfcc_to_fvec(mfcc_vectors)
                    feature_vector.append(spkr_dir)
                    melwriter.writerow(feature_vector)

    def get_tdata(self):
        mfcc_list = []
        speaker_names = []

        with open(self.train_file, 'r') as icsv_handle:
            melreader = csv.reader(icsv_handle)
            for row in melreader:
                mfcc_list.append(map(float, row[:-1]))
                speaker_names.append(row[-1])
        return mfcc_list, speaker_names
        
        
    def predict(self, soundclip):
        sample_rate, data = wavfile.read(os.path.abspath(soundclip))
        ceps = mfcc(data, sample_rate)
        fvec = self.mfcc_to_fvec(ceps)
        speaker_id = self.clf.predict([fvec])[0]
        return self.spkr_iton[speaker_id]



if __name__ == "__main__":
    trained_model = trainModel("train_data")

    test_dir = os.path.abspath("test_data")
    testset_size = 0
    testset_error = 0

    for spkr_dir in os.listdir(test_dir):
        for soundclip in os.listdir(os.path.join(test_dir, spkr_dir)):
            clippath = os.path.abspath(os.path.join(test_dir, spkr_dir, soundclip))
            prediction = trained_model.predict(clippath)
            
            testset_size += 1
            if prediction != spkr_dir:
                testset_error += 1    
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2717]")
            else:
                print "%s %s %s " % (prediction, spkr_dir, u"[\u2713]")

    if testset_size == 0:
        print "No test data available."
    else:
        print "Error on test data: %.2f%%\n" % (testset_error / testset_size * 100)
        print "Accuracy : %.2f%%\n" % (100-(testset_error / testset_size * 100))
# Out:
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# anthonyschaller anthonyschaller [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Apple_Eater Apple_Eater [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# Ara Ara [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# argail argail [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# arjuan arjuan [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# armond armond [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# Artem Artem [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# arthur arthur [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# artk artk [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arun arun [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# arvala arvala [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asalkeld asalkeld [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# asladic asladic [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# AslakKnutsen AslakKnutsen [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# asp asp [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# AT AT [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# ataru ataru [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# atterer atterer [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# audioodyssey audioodyssey [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# avsa avsa [✓]
# BobHallstrom ax [✗]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# ax ax [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# axllaruse axllaruse [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# azmisov azmisov [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bachroxx bachroxx [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# bae bae [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bareford Bareford [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# Bassel Bassel [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# bdutta bdutta [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# beady beady [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# bebe bebe [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# becz03 becz03 [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# belmontguy belmontguy [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# ben ben [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# bencoder bencoder [✓]
# arun bendauphinee [✗]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bendauphinee bendauphinee [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# bennmann bennmann [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benob benob [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# benoliver999 benoliver999 [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# Berrym Berrym [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# BFG BFG [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhart bhart [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# bhavanikrishna bhavanikrishna [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# BhushanNKIITBombay BhushanNKIITBombay [✓]
# blood bhuvan [✗]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# bhuvan bhuvan [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BigMick BigMick [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# BillMorgan BillMorgan [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Bitbrit Bitbrit [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blackdrive Blackdrive [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# Blenderkitty Blenderkitty [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# BlindPilot BlindPilot [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# blood blood [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# bloomtom bloomtom [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueAgent BlueAgent [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# BlueB BlueB [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluefox83 bluefox83 [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# bluSch bluSch [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# BobHallstrom BobHallstrom [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bobriva123 bobriva123 [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# bonzer bonzer [✓]
# Error on test data: 0.92%
#
# Accuracy : 99.08%
